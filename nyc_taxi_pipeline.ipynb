# %%
# Check Spark version and cluster info
print(f"Spark version: {spark.version}")
print(f"Cluster configured successfully!")

# Check available datasets
dbutils.fs.ls("/databricks-datasets/")
# Out:
# Spark version: 4.0.0
# Cluster configured successfully!
# [FileInfo(path='dbfs:/databricks-datasets/COVID/', name='COVID/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/README.md', name='README.md', size=976, modificationTime=1596557781000),
#  FileInfo(path='dbfs:/databricks-datasets/Rdatasets/', name='Rdatasets/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/SPARK_README.md', name='SPARK_README.md', size=3359, modificationTime=1596557823000),
#  FileInfo(path='dbfs:/databricks-datasets/adult/', name='adult/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/airlines/', name='airlines/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/amazon/', name='amazon/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/asa/', name='asa/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/atlas_higgs/', name='atlas_higgs/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/bikeSharing/', name='bikeSharing/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/cctvVideos/', name='cctvVideos/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/credit-card-fraud/', name='credit-card-fraud/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/cs100/', name='cs100/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/cs110x/', name='cs110x/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/cs190/', name='cs190/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/data.gov/', name='data.gov/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/definitive-guide/', name='definitive-guide/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/delta-sharing/', name='delta-sharing/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/flights/', name='flights/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/flower_photos/', name='flower_photos/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/flowers/', name='flowers/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/genomics/', name='genomics/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/hail/', name='hail/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/identifying-campaign-effectiveness/', name='identifying-campaign-effectiveness/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/iot/', name='iot/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/iot-stream/', name='iot-stream/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/learning-spark/', name='learning-spark/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/learning-spark-v2/', name='learning-spark-v2/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/lending-club-loan-stats/', name='lending-club-loan-stats/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/med-images/', name='med-images/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/media/', name='media/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/mnist-digits/', name='mnist-digits/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/news20.binary/', name='news20.binary/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/nyctaxi/', name='nyctaxi/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/nyctaxi-with-zipcodes/', name='nyctaxi-with-zipcodes/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/online_retail/', name='online_retail/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/overlap-join/', name='overlap-join/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/power-plant/', name='power-plant/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/retail-org/', name='retail-org/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/rwe/', name='rwe/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/sai-summit-2019-sf/', name='sai-summit-2019-sf/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/sample_logs/', name='sample_logs/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/samples/', name='samples/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/sfo_customer_survey/', name='sfo_customer_survey/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/sms_spam_collection/', name='sms_spam_collection/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/songs/', name='songs/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/structured-streaming/', name='structured-streaming/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/timeseries/', name='timeseries/', size=0, modificationTime=1762918301348),
#  FileInfo(path='dbfs:/databricks-datasets/tpch/', name='tpch/', size=0, modificationTime=1762918301349),
#  FileInfo(path='dbfs:/databricks-datasets/travel_recommendations_realtime/', name='travel_recommendations_realtime/', size=0, modificationTime=1762918301349),
#  FileInfo(path='dbfs:/databricks-datasets/warmup/', name='warmup/', size=0, modificationTime=1762918301349),
#  FileInfo(path='dbfs:/databricks-datasets/weather/', name='weather/', size=0, modificationTime=1762918301349),
#  FileInfo(path='dbfs:/databricks-datasets/wiki/', name='wiki/', size=0, modificationTime=1762918301349),
#  FileInfo(path='dbfs:/databricks-datasets/wikipedia-datasets/', name='wikipedia-datasets/', size=0, modificationTime=1762918301349),
#  FileInfo(path='dbfs:/databricks-datasets/wine-quality/', name='wine-quality/', size=0, modificationTime=1762918301349)]

# %%
from pyspark.sql import functions as F
from pyspark.sql.types import IntegerType, DoubleType, TimestampType
import time

# %%
nyc_taxi_df = spark.read.parquet(
    "/Volumes/workspace/default/nyc_taxi/yellow_tripdata_2019-*.parquet"
)

print(f"Rows: {nyc_taxi_df.count()}")
nyc_taxi_df.show(5)
# Out:
# Rows: 84598444
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+
# |VendorID|tpep_pickup_datetime|tpep_dropoff_datetime|passenger_count|trip_distance|RatecodeID|store_and_fwd_flag|PULocationID|DOLocationID|payment_type|fare_amount|extra|mta_tax|tip_amount|tolls_amount|improvement_surcharge|total_amount|congestion_surcharge|airport_fee|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+
# |       1| 2019-03-01 00:24:41|  2019-03-01 00:25:31|            1.0|          0.0|       1.0|                 N|         145|         145|           2|        2.5|  0.5|    0.5|       0.0|         0.0|                  0.3|         3.8|                 0.0|       NULL|
# |       1| 2019-03-01 00:25:27|  2019-03-01 00:36:37|            2.0|          3.7|       1.0|                 N|          95|         130|           1|       13.0|  0.5|    0.5|       0.7|         0.0|                  0.3|        15.0|                 0.0|       NULL|
# |       1| 2019-03-01 00:05:21|  2019-03-01 00:38:23|            1.0|         14.1|       1.0|                 N|         249|          28|           1|       41.0|  3.0|    0.5|      10.1|        5.76|                  0.3|       60.66|                 2.5|       NULL|
# |       1| 2019-03-01 00:48:55|  2019-03-01 01:06:03|            1.0|          9.6|       1.0|                 N|         138|          98|           2|       27.0|  0.5|    0.5|       0.0|         0.0|                  0.3|        28.3|                 0.0|       NULL|
# |       1| 2019-03-01 00:11:42|  2019-03-01 00:16:40|            1.0|          0.8|       1.0|                 N|          48|          48|           1|        5.5|  3.0|    0.5|       3.0|         0.0|                  0.3|        12.3|                 2.5|       NULL|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+
# only showing top 5 rows

# %%
nyc_taxi_df.printSchema()
# Out:
# root
#  |-- VendorID: long (nullable = true)
#  |-- tpep_pickup_datetime: timestamp_ntz (nullable = true)
#  |-- tpep_dropoff_datetime: timestamp_ntz (nullable = true)
#  |-- passenger_count: double (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- RatecodeID: double (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- PULocationID: long (nullable = true)
#  |-- DOLocationID: long (nullable = true)
#  |-- payment_type: long (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- extra: double (nullable = true)
#  |-- mta_tax: double (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- tolls_amount: double (nullable = true)
#  |-- improvement_surcharge: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- congestion_surcharge: double (nullable = true)
#  |-- airport_fee: integer (nullable = true)

# %%
cols_needed = [
    "tpep_pickup_datetime", "tpep_dropoff_datetime", "passenger_count",
    "trip_distance", "PULocationID", "DOLocationID", "payment_type", "fare_amount", "tip_amount", "total_amount"
]

nyc_taxi_df_trimmed = nyc_taxi_df.select(*[c for c in cols_needed if c in nyc_taxi_df.columns])

# %%
nyc_taxi_df_trimmed = (nyc_taxi_df_trimmed
      .withColumn("pickup_dt", F.to_timestamp("tpep_pickup_datetime"))
      .withColumn("dropoff_dt", F.to_timestamp("tpep_dropoff_datetime"))
      .withColumn("trip_seconds", 
                  (F.unix_timestamp("dropoff_dt") - F.unix_timestamp("pickup_dt")).cast(IntegerType()))
      .withColumn("cost_per_mile", 
                  F.when(F.col("trip_distance")>0, F.col("total_amount")/F.col("trip_distance")).otherwise(None))
      .withColumn("year", F.year("pickup_dt"))
      .withColumn("month", F.month("pickup_dt"))
     )

nyc_taxi_df_trimmed = nyc_taxi_df_trimmed.filter((F.col("trip_distance") > 0) & (F.col("trip_seconds") > 0) & (F.col("total_amount") >= 0))

# %%
nyc_taxi_df_filtered = (nyc_taxi_df_trimmed
            .filter(F.col("year") == 2019)
            .filter(F.col("trip_distance") < 100)
            .filter(F.col("passenger_count").between(1,6))
           )

print("Filtered count:", nyc_taxi_df_filtered.count())
# Out:
# Filtered count: 81761875

# %%
nyc_taxi_df_filtered_aggregate = (nyc_taxi_df_filtered
       .withColumn("hour", F.hour("pickup_dt"))
       .groupBy("PULocationID", "hour")
       .agg(
           F.count("*").alias("n_trips"),
           F.avg("tip_amount").alias("avg_tip"),
           F.avg("total_amount").alias("avg_total")
       )
       .filter(F.col("n_trips") > 50)
       .orderBy(F.desc("n_trips"))
      )
display(nyc_taxi_df_filtered_aggregate.limit(50))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>PULocationID</th><th>hour</th><th>n_trips</th><th>avg_tip</th><th>avg_total</th></tr></thead><tbody><tr><td>237</td><td>18</td><td>262763</td><td>1.782155478511069</td><td>15.052447871272758</td></tr><tr><td>237</td><td>14</td><td>259886</td><td>1.6719072208583865</td><td>14.461724025146653</td></tr><tr><td>237</td><td>15</td><td>254915</td><td>1.6386837573308837</td><td>14.349240413468397</td></tr><tr><td>237</td><td>17</td><td>251552</td><td>1.7884368639486201</td><td>15.366496549418374</td></tr><tr><td>161</td><td>19</td><td>249342</td><td>2.0351082449005955</td><td>16.897644480269065</td></tr><tr><td>236</td><td>15</td><td>248721</td><td>1.6846729065901234</td><td>14.685151233708943</td></tr><tr><td>161</td><td>18</td><td>244925</td><td>2.092352271103415</td><td>17.685739430434705</td></tr><tr><td>230</td><td>22</td><td>238005</td><td>2.048803008340178</td><td>17.261519463873707</td></tr><tr><td>162</td><td>18</td><td>235888</td><td>2.1765007122024165</td><td>17.429331759137142</td></tr><tr><td>237</td><td>13</td><td>234691</td><td>1.6399080066981762</td><td>14.365251202642654</td></tr><tr><td>237</td><td>12</td><td>233685</td><td>1.6139724415345507</td><td>14.162909857284037</td></tr><tr><td>237</td><td>16</td><td>228802</td><td>1.742039754897254</td><td>15.212085864631424</td></tr><tr><td>161</td><td>20</td><td>227614</td><td>2.081087455077471</td><td>16.604169778657777</td></tr><tr><td>236</td><td>17</td><td>227533</td><td>1.7921757283558932</td><td>15.297004610317765</td></tr><tr><td>162</td><td>19</td><td>224766</td><td>2.1361081302332368</td><td>16.848463246217978</td></tr><tr><td>236</td><td>18</td><td>224423</td><td>1.7907012204631534</td><td>14.926027100606822</td></tr><tr><td>237</td><td>19</td><td>224338</td><td>1.7550419010600176</td><td>17.59133771362767</td></tr><tr><td>161</td><td>14</td><td>223226</td><td>2.214842536263707</td><td>18.663696388410504</td></tr><tr><td>236</td><td>14</td><td>222547</td><td>1.6602326699528662</td><td>14.507114766766023</td></tr><tr><td>236</td><td>12</td><td>222397</td><td>1.690813365288207</td><td>14.495025562392913</td></tr><tr><td>161</td><td>17</td><td>222322</td><td>2.1529787875244155</td><td>18.42438899433854</td></tr><tr><td>161</td><td>21</td><td>221449</td><td>2.202904054658198</td><td>16.84072350744177</td></tr><tr><td>161</td><td>15</td><td>216944</td><td>2.16160691238293</td><td>18.32239329043146</td></tr><tr><td>237</td><td>11</td><td>213472</td><td>1.6320093970169423</td><td>14.213421760228703</td></tr><tr><td>236</td><td>16</td><td>212019</td><td>1.7556380324404923</td><td>15.294358854628603</td></tr><tr><td>162</td><td>17</td><td>210898</td><td>2.2470893512503793</td><td>18.170071693422642</td></tr><tr><td>236</td><td>8</td><td>208538</td><td>1.9817198304385848</td><td>15.450688123985072</td></tr><tr><td>236</td><td>13</td><td>208497</td><td>1.6710243792476691</td><td>14.48848626119112</td></tr><tr><td>161</td><td>13</td><td>207438</td><td>2.1646251892131696</td><td>18.44529922193332</td></tr><tr><td>236</td><td>11</td><td>206818</td><td>1.730318734346144</td><td>14.586681284992528</td></tr><tr><td>162</td><td>20</td><td>206254</td><td>2.231764183967355</td><td>16.780652399466522</td></tr><tr><td>230</td><td>21</td><td>204880</td><td>1.995780798516212</td><td>16.86607648379284</td></tr><tr><td>161</td><td>16</td><td>203541</td><td>2.2001625716686166</td><td>18.915514318979568</td></tr><tr><td>161</td><td>22</td><td>199356</td><td>2.2128893537189867</td><td>17.055625413830338</td></tr><tr><td>236</td><td>10</td><td>198912</td><td>1.7388623612451788</td><td>14.361518058235033</td></tr><tr><td>161</td><td>12</td><td>197469</td><td>2.0925589839417897</td><td>18.051808030624954</td></tr><tr><td>236</td><td>9</td><td>197288</td><td>1.889250182474359</td><td>15.061991808927269</td></tr><tr><td>48</td><td>22</td><td>196768</td><td>2.0961289437306956</td ...

# %%
nyc_taxi_df_filtered_daily_stats = (nyc_taxi_df_filtered
               .withColumn("pickup_date", F.to_date("pickup_dt"))
               .groupBy("pickup_date")
               .agg(
                   F.count("*").alias("trips"),
                   F.sum("trip_distance").alias("sum_distance"),
                   F.avg("fare_amount").alias("avg_fare"),
                   F.avg("cost_per_mile").alias("avg_cost_per_mile")
               )
               .orderBy("pickup_date")
              )
display(nyc_taxi_df_filtered_daily_stats.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>pickup_date</th><th>trips</th><th>sum_distance</th><th>avg_fare</th><th>avg_cost_per_mile</th></tr></thead><tbody><tr><td>2019-01-01</td><td>184733</td><td>658065.8899999907</td><td>13.576036008726112</td><td>8.691470048130315</td></tr><tr><td>2019-01-02</td><td>193401</td><td>625974.8899999988</td><td>12.987656630524143</td><td>9.877036052276798</td></tr><tr><td>2019-01-03</td><td>217898</td><td>649918.3700000047</td><td>12.510801108775647</td><td>9.776335915169437</td></tr><tr><td>2019-01-04</td><td>229688</td><td>650575.460000009</td><td>12.047309350074878</td><td>9.305713685935439</td></tr><tr><td>2019-01-05</td><td>231092</td><td>620001.3000000006</td><td>11.357736096446425</td><td>9.086749183085296</td></tr><tr><td>2019-01-06</td><td>203634</td><td>630749.2899999899</td><td>12.29189658897825</td><td>9.212683429959348</td></tr><tr><td>2019-01-07</td><td>222514</td><td>639902.1300000112</td><td>12.11741719622136</td><td>9.602806992143757</td></tr><tr><td>2019-01-08</td><td>230858</td><td>644410.6800000038</td><td>12.07237453326285</td><td>9.339118097465365</td></tr><tr><td>2019-01-09</td><td>248989</td><td>686445.9599999953</td><td>12.07002373598833</td><td>9.650481696055488</td></tr><tr><td>2019-01-10</td><td>274325</td><td>752054.4800000101</td><td>12.168949931650403</td><td>9.652038471709073</td></tr></tbody></table></div>

# %%
nyc_taxi_df_filtered.createOrReplaceTempView("trips_filtered")

sql_1 = spark.sql("""
SELECT PULocationID, COUNT(*) AS trip_count, AVG(total_amount) AS avg_total
FROM trips_filtered
GROUP BY PULocationID
ORDER BY trip_count DESC
LIMIT 50
""")
display(sql_1)

sql_2 = spark.sql("""
SELECT hour(pickup_dt) AS hour_of_day, 
       COUNT(*) AS trips,
       AVG(CASE WHEN total_amount > 0 THEN tip_amount/total_amount ELSE NULL END) AS avg_tip_rate
FROM trips_filtered
GROUP BY hour_of_day
ORDER BY hour_of_day
""")
display(sql_2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>PULocationID</th><th>trip_count</th><th>avg_total</th></tr></thead><tbody><tr><td>237</td><td>3558623</td><td>14.786242178466004</td></tr><tr><td>161</td><td>3367811</td><td>17.806076103988737</td></tr><tr><td>236</td><td>3218419</td><td>14.903735212816118</td></tr><tr><td>162</td><td>2974213</td><td>17.42958801871112</td></tr><tr><td>186</td><td>2943209</td><td>17.81265454810834</td></tr><tr><td>230</td><td>2823856</td><td>19.07906584467504</td></tr><tr><td>132</td><td>2613346</td><td>56.40362840207042</td></tr><tr><td>48</td><td>2606595</td><td>16.941972600238717</td></tr><tr><td>170</td><td>2534856</td><td>17.173273243108266</td></tr><tr><td>234</td><td>2472886</td><td>16.392720978624222</td></tr><tr><td>142</td><td>2472234</td><td>15.930094752336355</td></tr><tr><td>163</td><td>2201923</td><td>17.900936758438284</td></tr><tr><td>239</td><td>2133273</td><td>15.491635744689722</td></tr><tr><td>138</td><td>2104033</td><td>43.492471933617324</td></tr><tr><td>79</td><td>2089584</td><td>16.601761862635744</td></tr><tr><td>68</td><td>1980839</td><td>17.31886417824754</td></tr><tr><td>141</td><td>1913906</td><td>14.82335050938059</td></tr><tr><td>164</td><td>1910048</td><td>17.376924731724483</td></tr><tr><td>107</td><td>1848676</td><td>16.32065452788749</td></tr><tr><td>100</td><td>1674377</td><td>17.19541834366106</td></tr><tr><td>238</td><td>1623366</td><td>15.26516618557986</td></tr><tr><td>249</td><td>1591845</td><td>16.444951505965093</td></tr><tr><td>229</td><td>1552469</td><td>15.689365829540794</td></tr><tr><td>263</td><td>1509699</td><td>15.106019140254064</td></tr><tr><td>140</td><td>1462318</td><td>16.5116070512849</td></tr><tr><td>90</td><td>1426246</td><td>15.888297642916818</td></tr><tr><td>231</td><td>1359219</td><td>19.18278327481606</td></tr><tr><td>246</td><td>1346428</td><td>17.5603222452434</td></tr><tr><td>43</td><td>1286936</td><td>16.368724707382054</td></tr><tr><td>113</td><td>1243216</td><td>16.25665871418709</td></tr><tr><td>233</td><td>1070842</td><td>17.943973452679405</td></tr><tr><td>114</td><td>1041265</td><td>16.839870109926792</td></tr><tr><td>148</td><td>1006628</td><td>18.21997213470482</td></tr><tr><td>262</td><td>996272</td><td>15.975087335598912</td></tr><tr><td>137</td><td>964499</td><td>16.079212586027996</td></tr><tr><td>143</td><td>957766</td><td>15.53438729294048</td></tr><tr><td>158</td><td>824232</td><td>17.897914494958385</td></tr><tr><td>144</td><td>799335</td><td>17.627119305433535</td></tr><tr><td>50</td><td>720740</td><td>17.05231055582707</td></tr><tr><td>13</td><td>720020</td><td>22.75059248355305</td></tr><tr><td>151</td><td>719227</td><td>14.76999352082886</td></tr><tr><td>264</td><td>690724</td><td>18.134557565693807</td></tr><tr><td>211</td><td>645036</td><td>17.378216859221578</td></tr><tr><td>75</td><td>598249</td><td>14.70704056338217</td></tr><tr><td>87</td><td>578246</td><td>23.506795516104805</td></tr><tr><td>261</td><td>477052</td><td>23.282678911321852</td></tr><tr><td>125</td><td>458222</td><td>17.709102400148424</td></tr><tr><td>166</td><td>445831</td><td>16.066595907417465</td></tr><tr><td>74</td><td>313711</td><td>13.944014140398263</td></tr><tr><td>41</td><td>309173</td><td>13.637462165191296</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>hour_of_day</th><th>trips</th><th>avg_tip_rate</th></tr></thead><tbody><tr><td>0</td><td>2426028</td><td>0.10973029553420509</td></tr><tr><td>1</td><td>1685005</td><td>0.10778207162148955</td></tr><tr><td>2</td><td>1167226</td><td>0.10489055118733699</td></tr><tr><td>3</td><td>811732</td><td>0.09861668098677273</td></tr><tr><td>4</td><td>625218</td><td>0.0863772029217584</td></tr><tr><td>5</td><td>736134</td><td>0.09240369977737835</td></tr><tr><td>6</td><td>1689658</td><td>0.10197196840144508</td></tr><tr><td>7</td><td>2969422</td><td>0.11174050402724967</td></tr><tr><td>8</td><td>3726209</td><td>0.11485282295316052</td></tr><tr><td>9</td><td>3802137</td><td>0.11141905628358878</td></tr><tr><td>10</td><td>3843298</td><td>0.10698089891145426</td></tr><tr><td>11</td><td>4033362</td><td>0.10547083385097689</td></tr><tr><td>12</td><td>4279174</td><td>0.10488145077234384</td></tr><tr><td>13</td><td>4318991</td><td>0.10411201737312617</td></tr><tr><td>14</td><td>4546427</td><td>0.10426411928669385</td></tr><tr><td>15</td><td>4568340</td><td>0.10429220843149624</td></tr><tr><td>16</td><td>4293607</td><td>0.10457638742885662</td></tr><tr><td>17</td><td>4862903</td><td>0.10800009242486308</td></tr><tr><td>18</td><td>5376523</td><td>0.11107651947603454</td></tr><tr><td>19</td><td>5087210</td><td>0.11231065458619949</td></tr><tr><td>20</td><td>4645047</td><td>0.11446304070482952</td></tr><tr><td>21</td><td>4600828</td><td>0.11519729857380911</td></tr><tr><td>22</td><td>4282413</td><td>0.11499977600960438</td></tr><tr><td>23</td><td>3384983</td><td>0.1120442674339482</td></tr></tbody></table></div>

# %%
print("=== EXPLAIN for sql_1 ===")
sql_1.explain(True)

print("=== EXPLAIN for agg ===")
nyc_taxi_df_filtered_aggregate.explain(True)
# Out:
# === EXPLAIN for sql_1 ===
# == Parsed Logical Plan ==
# 'GlobalLimit 50
# +- 'LocalLimit 50
#    +- 'Sort ['trip_count DESC NULLS LAST], true
#       +- 'Aggregate ['PULocationID], ['PULocationID, 'COUNT(1) AS trip_count#11330, 'AVG('total_amount) AS avg_total#11331]
#          +- 'UnresolvedRelation [trips_filtered], [], false
#
# == Analyzed Logical Plan ==
# PULocationID: bigint, trip_count: bigint, avg_total: double
# GlobalLimit 50
# +- LocalLimit 50
#    +- Sort [trip_count#11330L DESC NULLS LAST], true
#       +- Aggregate [PULocationID#11045L], [PULocationID#11045L, count(1) AS trip_count#11330L, avg(total_amount#11054) AS avg_total#11331]
#          +- SubqueryAlias trips_filtered
#             +- View (`trips_filtered`, [tpep_pickup_datetime#11039, tpep_dropoff_datetime#11040, passenger_count#11041, trip_distance#11042, PULocationID#11045L, DOLocationID#11046L, payment_type#11047L, fare_amount#11048, tip_amount#11051, total_amount#11054, pickup_dt#11126, dropoff_dt#11128, trip_seconds#11130, cost_per_mile#11132, year#11134, month#11136])
#                +- Filter ((passenger_count#11041 >= cast(1 as double)) AND (passenger_count#11041 <= cast(6 as double)))
#                   +- Filter (trip_distance#11042 < cast(100 as double))
#                      +- Filter (year#11134 = 2019)
#                         +- Filter (((trip_distance#11042 > cast(0 as double)) AND (trip_seconds#11130 > 0)) AND (total_amount#11054 >= cast(0 as double)))
#                            +- Project [tpep_pickup_datetime#11039, tpep_dropoff_datetime#11040, passenger_count#11041, trip_distance#11042, PULocationID#11045L, DOLocationID#11046L, payment_type#11047L, fare_amount#11048, tip_amount#11051, total_amount#11054, pickup_dt#11126, dropoff_dt#11128, trip_seconds#11130, cost_per_mile#11132, year#11134, month(cast(pickup_dt#11126 as date)) AS month#11136]
#                               +- Project [tpep_pickup_datetime#11039, tpep_dropoff_datetime#11040, passenger_count#11041, trip_distance#11042, PULocationID#11045L, DOLocationID#11046L, payment_type#11047L, fare_amount#11048, tip_amount#11051, total_amount#11054, pickup_dt#11126, dropoff_dt#11128, trip_seconds#11130, cost_per_mile#11132, year(cast(pickup_dt#11126 as date)) AS year#11134]
#                                  +- Project [tpep_pickup_datetime#11039, tpep_dropoff_datetime#11040, passenger_count#11041, trip_distance#11042, PULocationID#11045L, DOLocationID#11046L, payment_type#11047L, fare_amount#11048, tip_amount#11051, total_amount#11054, pickup_dt#11126, dropoff_dt#11128, trip_seconds#11130, CASE WHEN (trip_distance#11042 > cast(0 as double)) THEN (total_amount#11054 / trip_distance#11042) ELSE cast(null as double) END AS cost_per_mile#11132]
#                                     +- Project [tpep_pickup_datetime#11039, tpep_dropoff_datetime#11040, passenger_count#11041, trip_distance#11042, PULocationID#11045L, DOLocationID#11046L, payment_type#11047L, fare_amount#11048, tip_amount#11051, total_amount#11054, pickup_dt#11126, dropoff_dt#11128, cast((unix_timestamp(dropoff_dt#11128, yyyy-MM-dd HH:mm:ss, Some(Etc/UTC), true) - unix_timestamp(pickup_dt#11126, yyyy-MM-dd HH:mm:ss, Some(Etc/UTC), true)) as int) AS trip_seconds#11130]
#                                        +- Project [tpep_pickup_datetime#11039, tpep_dropoff_datetime#11040, passenger_count#11041, trip_distance#11042, PULocationID#11045L, DOLocationID#11046L, payment_type#11047L, fare_amount#11048, tip_amount#11051, total_amount#11054, pickup_dt#11126, to_timestamp(tpep_dropoff_datetime#11040, None, TimestampType, Some(Etc/UTC), true) AS dropoff_dt#11128]
#                                           +- Project [tpep_pickup_datetime#11039, tpep_dropoff_datetime#11040, passenger_count#11041, trip_distance#11042, PULocationID#11045L, DOLocationID#11046L, payment_type#11047L, fare_amount#11048, tip_amount#11051, total_amount#11054, to_timestamp(tpep_pickup_datetime#11039, None, TimestampType, Some(Etc/UTC), true) AS pickup_dt#11126]
#                                              +- Project [tpep_pickup_datetime#11039, tpep_dropoff_datetime#11040, passenger_count#11041, trip_distance#11042, PULocationID#11045L, DOLocationID#11046L, payment_type#11047L, fare_amount#11048, tip_amount#11051, total_amount#11054]
#                                                 +- Relation [VendorID#11038L,tpep_pickup_datetime#11039,tpep_dropoff_datetime#11040,passenger_count#11041,trip_distance#11042,RatecodeID#11043,store_and_fwd_flag#11044,PULocationID#11045L,DOLocationID#11046L,payment_type#11047L,fare_amount#11048,extra#11049,mta_tax#11050,tip_amount#11051,tolls_amount#11052,improvement_surcharge#11053,total_amount#11054,congestion_surcharge#11055,airport_fee#11056] parquet
#
# == Optimized Logical Plan ==
# GlobalLimit 50
# +- LocalLimit 50
#    +- Sort [trip_count#11330L DESC NULLS LAST], true
#       +- Aggregate [PULocationID#11045L], [PULocationID#11045L, count(1) AS trip_count#11330L, avg(total_amount#11054) AS avg_total#11331]
#          +- Project [PULocationID#11045L, total_amount#11054]
#             +- Filter ((((((((((isnotnull(trip_distance#11042) AND isnotnull(total_amount#11054)) AND isnotnull(tpep_pickup_datetime#11039)) AND isnotnull(passenger_count#11041)) AND (trip_distance#11042 > 0.0)) AND (total_amount#11054 >= 0.0)) AND (trip_distance#11042 < 100.0)) AND (passenger_count#11041 >= 1.0)) AND (passenger_count#11041 <= 6.0)) AND (year(cast(cast(tpep_pickup_datetime#11039 as timestamp) as date)) = 2019)) AND (cast((unix_timestamp(cast(tpep_dropoff_datetime#11040 as timestamp), yyyy-MM-dd HH:mm:ss, Some(Etc/UTC), true) - unix_timestamp(cast(tpep_pickup_datetime#11039 as timestamp), yyyy-MM-dd HH:mm:ss, Some(Etc/UTC), true)) as int) > 0))
#                +- Relation [VendorID#11038L,tpep_pickup_datetime#11039,tpep_dropoff_datetime#11040,passenger_count#11041,trip_distance#11042,RatecodeID#11043,store_and_fwd_flag#11044,PULocationID#11045L,DOLocationID#11046L,payment_type#11047L,fare_amount#11048,extra#11049,mta_tax#11050,tip_amount#11051,tolls_amount#11052,improvement_surcharge#11053,total_amount#11054,congestion_surcharge#11055,airport_fee#11056] parquet
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- == Initial Plan ==
#    ColumnarToRow
#    +- PhotonResultStage
#       +- PhotonTopK(limit=50, includeTies=false, sortOrder=[trip_count#11330L DESC NULLS LAST], partitionOrderCount=0)
#          +- PhotonShuffleExchangeSource
#             +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#8512]
#                +- PhotonShuffleExchangeSink SinglePartition
#                   +- PhotonTopK(limit=50, includeTies=false, sortOrder=[trip_count#11330L DESC NULLS LAST], partitionOrderCount=0)
#                      +- PhotonGroupingAgg(limit=None, keys=[PULocationID#11045L], functions=[finalmerge_count(merge count#11440L) AS count(1)#11437L, finalmerge_avg(merge sum#11443, count#11444L) AS avg(total_amount)#11438], output=[PULocationID#11045L, trip_count#11330L, avg_total#11331])
#                         +- PhotonShuffleExchangeSource
#                            +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#8504]
#                               +- PhotonShuffleExchangeSink hashpartitioning(PULocationID#11045L, 1024)
#                                  +- PhotonGroupingAgg(limit=None, keys=[PULocationID#11045L], functions=[partial_count(1) AS count#11440L, partial_avg(total_amount#11054) AS (sum#11443, count#11444L)], output=[PULocationID#11045L, count#11440L, sum#11443, count#11444L])
#                                     +- PhotonProject [PULocationID#11045L, total_amount#11054]
#                                        +- PhotonScan parquet [tpep_pickup_datetime#11039,tpep_dropoff_datetime#11040,passenger_count#11041,trip_distance#11042,PULocationID#11045L,total_amount#11054] DataFilters: [isnotnull(trip_distance#11042), isnotnull(total_amount#11054), isnotnull(tpep_pickup_datetime#11..., DictionaryFilters: [((trip_distance#11042 > 0.0) AND (trip_distance#11042 < 100.0)), ((passenger_count#11041 >= 1.0)..., Format: parquet, Location: InMemoryFileIndex(12 paths)[dbfs:/Volumes/workspace/default/nyc_taxi/yellow_tripdata_2019-01.parq..., OptionalDataFilters: [], PartitionFilters: [], ReadSchema: struct<tpep_pickup_datetime:timestamp_ntz,tpep_dropoff_datetime:timestamp_ntz,passenger_count:dou..., RequiredDataFilters: [isnotnull(trip_distance#11042), isnotnull(total_amount#11054), isnotnull(tpep_pickup_datetime#11...
#
# == Photon Explanation ==
# The query is fully supported by Photon.
# === EXPLAIN for agg ===
# == Parsed Logical Plan ==
# 'Sort ['n_trips DESC NULLS LAST], true
# +- 'Filter '`>`('n_trips, 50)
#    +- 'Aggregate ['PULocationID, 'hour], ['PULocationID, 'hour, 'count(*) AS n_trips#11236, 'avg('tip_amount) AS avg_tip#11237, 'avg('total_amount) AS avg_total#11238]
#       +- Project [tpep_pickup_datetime#11039, tpep_dropoff_datetime#11040, passenger_count#11041, trip_distance#11042, PULocationID#11045L, DOLocationID#11046L, payment_type#11047L, fare_amount#11048, tip_amount#11051, total_amount#11054, pickup_dt#11126, dropoff_dt#11128, trip_seconds#11130, cost_per_mile#11132, year#11134, month#11136, hour(pickup_dt#11126, Some(Etc/UTC)) AS hour#11235]
#          +- Filter ((passenger_count#11041 >= cast(1 as double)) AND (passenger_count#11041 <= cast(6 as double)))
#             +- Filter (trip_distance#11042 < cast(100 as double))
#                +- Filter (year#11134 = 2019)
#                   +- Filter (((trip_distance#11042 > cast(0 as double)) AND (trip_seconds#11130 > 0)) AND (total_amount#11054 >= cast(0 as double)))
#                      +- Project [tpep_pickup_datetime#11039, tpep_dropoff_datetime#11040, passenger_count#11041, trip_distance#11042, PULocationID#11045L, DOLocationID#11046L, payment_type#11047L, fare_amount#11048, tip_amount#11051, total_amount#11054, pickup_dt#11126, dropoff_dt#11128, trip_seconds#11130, cost_per_mile#11132, year#11134, month(cast(pickup_dt#11126 as date)) AS month#11136]
#                         +- Project [tpep_pickup_datetime#11039, tpep_dropoff_datetime#11040, passenger_count#11041, trip_distance#11042, PULocationID#11045L, DOLocationID#11046L, payment_type#11047L, fare_amount#11048, tip_amount#11051, total_amount#11054, pickup_dt#11126, dropoff_dt#11128, trip_seconds#11130, cost_per_mile#11132, year(cast(pickup_dt#11126 as date)) AS year#11134]
#                            +- Project [tpep_pickup_datetime#11039, tpep_dropoff_datetime#11040, passenger_count#11041, trip_distance#11042, PULocationID#11045L, DOLocationID#11046L, payment_type#11047L, fare_amount#11048, tip_amount#11051, total_amount#11054, pickup_dt#11126, dropoff_dt#11128, trip_seconds#11130, CASE WHEN (trip_distance#11042 > cast(0 as double)) THEN (total_amount#11054 / trip_distance#11042) ELSE cast(null as double) END AS cost_per_mile#11132]
#                               +- Project [tpep_pickup_datetime#11039, tpep_dropoff_datetime#11040, passenger_count#11041, trip_distance#11042, PULocationID#11045L, DOLocationID#11046L, payment_type#11047L, fare_amount#11048, tip_amount#11051, total_amount#11054, pickup_dt#11126, dropoff_dt#11128, cast((unix_timestamp(dropoff_dt#11128, yyyy-MM-dd HH:mm:ss, Some(Etc/UTC), true) - unix_timestamp(pickup_dt#11126, yyyy-MM-dd HH:mm:ss, Some(Etc/UTC), true)) as int) AS trip_seconds#11130]
#                                  +- Project [tpep_pickup_datetime#11039, tpep_dropoff_datetime#11040, passenger_count#11041, trip_distance#11042, PULocationID#11045L, DOLocationID#11046L, payment_type#11047L, fare_amount#11048, tip_amount#11051, total_amount#11054, pickup_dt#11126, to_timestamp(tpep_dropoff_datetime#11040, None, TimestampType, Some(Etc/UTC), true) AS dropoff_dt#11128]
#                                     +- Project [tpep_pickup_datetime#11039, tpep_dropoff_datetime#11040, passenger_count#11041, trip_distance#11042, PULocationID#11045L, DOLocationID#11046L, payment_type#11047L, fare_amount#11048, tip_amount#11051, total_amount#11054, to_timestamp(tpep_pickup_datetime#11039, None, TimestampType, Some(Etc/UTC), true) AS pickup_dt#11126]
#                                        +- Project [tpep_pickup_datetime#11039, tpep_dropoff_datetime#11040, passenger_count#11041, trip_distance#11042, PULocationID#11045L, DOLocationID#11046L, payment_type#11047L, fare_amount#11048, tip_amount#11051, total_amount#11054]
#                                           +- Relation [VendorID#11038L,tpep_pickup_datetime#11039,tpep_dropoff_datetime#11040,passenger_count#11041,trip_distance#11042,RatecodeID#11043,store_and_fwd_flag#11044,PULocationID#11045L,DOLocationID#11046L,payment_type#11047L,fare_amount#11048,extra#11049,mta_tax#11050,tip_amount#11051,tolls_amount#11052,improvement_surcharge#11053,total_amount#11054,congestion_surcharge#11055,airport_fee#11056] parquet
#
# == Analyzed Logical Plan ==
# PULocationID: bigint, hour: int, n_trips: bigint, avg_tip: double, avg_total: double
# Sort [n_trips#11236L DESC NULLS LAST], true
# +- Filter (n_trips#11236L > cast(50 as bigint))
#    +- Aggregate [PULocationID#11045L, hour#11235], [PULocationID#11045L, hour#11235, count(1) AS n_trips#11236L, avg(tip_amount#11051) AS avg_tip#11237, avg(total_amount#11054) AS avg_total#11238]
#       +- Project [tpep_pickup_datetime#11039, tpep_dropoff_datetime#11040, passenger_count#11041, trip_distance#11042, PULocationID#11045L, DOLocationID#11046L, payment_type#11047L, fare_amount#11048, tip_amount#11051, total_amount#11054, pickup_dt#11126, dropoff_dt#11128, trip_seconds#11130, cost_per_mile#11132, year#11134, month#11136, hour(pickup_dt#11126, Some(Etc/UTC)) AS hour#11235]
#          +- Filter ((passenger_count#11041 >= cast(1 as double)) AND (passenger_count#11041 <= cast(6 as double)))
#             +- Filter (trip_distance#11042 < cast(100 as double))
#                +- Filter (year#11134 = 2019)
#                   +- Filter (((trip_distance#11042 > cast(0 as double)) AND (trip_seconds#11130 > 0)) AND (total_amount#11054 >= cast(0 as double)))
#                      +- Project [tpep_pickup_datetime#11039, tpep_dropoff_datetime#11040, passenger_count#11041, trip_distance#11042, PULocationID#11045L, DOLocationID#11046L, payment_type#11047L, fare_amount#11048, tip_amount#11051, total_amount#11054, pickup_dt#11126, dropoff_dt#11128, trip_seconds#11130, cost_per_mile#11132, year#11134, month(cast(pickup_dt#11126 as date)) AS month#11136]
#                         +- Project [tpep_pickup_datetime#11039, tpep_dropoff_datetime#11040, passenger_count#11041, trip_distance#11042, PULocationID#11045L, DOLocationID#11046L, payment_type#11047L, fare_amount#11048, tip_amount#11051, total_amount#11054, pickup_dt#11126, dropoff_dt#11128, trip_seconds#11130, cost_per_mile#11132, year(cast(pickup_dt#11126 as date)) AS year#11134]
#                            +- Project [tpep_pickup_datetime#11039, tpep_dropoff_datetime#11040, passenger_count#11041, trip_distance#11042, PULocationID#11045L, DOLocationID#11046L, payment_type#11047L, fare_amount#11048, tip_amount#11051, total_amount#11054, pickup_dt#11126, dropoff_dt#11128, trip_seconds#11130, CASE WHEN (trip_distance#11042 > cast(0 as double)) THEN (total_amount#11054 / trip_distance#11042) ELSE cast(null as double) END AS cost_per_mile#11132]
#                               +- Project [tpep_pickup_datetime#11039, tpep_dropoff_datetime#11040, passenger_count#11041, trip_distance#11042, PULocationID#11045L, DOLocationID#11046L, payment_type#11047L, fare_amount#11048, tip_amount#11051, total_amount#11054, pickup_dt#11126, dropoff_dt#11128, cast((unix_timestamp(dropoff_dt#11128, yyyy-MM-dd HH:mm:ss, Some(Etc/UTC), true) - unix_timestamp(pickup_dt#11126, yyyy-MM-dd HH:mm:ss, Some(Etc/UTC), true)) as int) AS trip_seconds#11130]
#                                  +- Project [tpep_pickup_datetime#11039, tpep_dropoff_datetime#11040, passenger_count#11041, trip_distance#11042, PULocationID#11045L, DOLocationID#11046L, payment_type#11047L, fare_amount#11048, tip_amount#11051, total_amount#11054, pickup_dt#11126, to_timestamp(tpep_dropoff_datetime#11040, None, TimestampType, Some(Etc/UTC), true) AS dropoff_dt#11128]
#                                     +- Project [tpep_pickup_datetime#11039, tpep_dropoff_datetime#11040, passenger_count#11041, trip_distance#11042, PULocationID#11045L, DOLocationID#11046L, payment_type#11047L, fare_amount#11048, tip_amount#11051, total_amount#11054, to_timestamp(tpep_pickup_datetime#11039, None, TimestampType, Some(Etc/UTC), true) AS pickup_dt#11126]
#                                        +- Project [tpep_pickup_datetime#11039, tpep_dropoff_datetime#11040, passenger_count#11041, trip_distance#11042, PULocationID#11045L, DOLocationID#11046L, payment_type#11047L, fare_amount#11048, tip_amount#11051, total_amount#11054]
#                                           +- Relation [VendorID#11038L,tpep_pickup_datetime#11039,tpep_dropoff_datetime#11040,passenger_count#11041,trip_distance#11042,RatecodeID#11043,store_and_fwd_flag#11044,PULocationID#11045L,DOLocationID#11046L,payment_type#11047L,fare_amount#11048,extra#11049,mta_tax#11050,tip_amount#11051,tolls_amount#11052,improvement_surcharge#11053,total_amount#11054,congestion_surcharge#11055,airport_fee#11056] parquet
#
# == Optimized Logical Plan ==
# Sort [n_trips#11236L DESC NULLS LAST], true
# +- Filter (n_trips#11236L > 50)
#    +- Aggregate [PULocationID#11045L, hour#11235], [PULocationID#11045L, hour#11235, count(1) AS n_trips#11236L, avg(tip_amount#11051) AS avg_tip#11237, avg(total_amount#11054) AS avg_total#11238]
#       +- Project [PULocationID#11045L, tip_amount#11051, total_amount#11054, hour(cast(tpep_pickup_datetime#11039 as timestamp), Some(Etc/UTC)) AS hour#11235]
#          +- Filter ((((((((((isnotnull(trip_distance#11042) AND isnotnull(total_amount#11054)) AND isnotnull(tpep_pickup_datetime#11039)) AND isnotnull(passenger_count#11041)) AND (trip_distance#11042 > 0.0)) AND (total_amount#11054 >= 0.0)) AND (trip_distance#11042 < 100.0)) AND (passenger_count#11041 >= 1.0)) AND (passenger_count#11041 <= 6.0)) AND (year(cast(cast(tpep_pickup_datetime#11039 as timestamp) as date)) = 2019)) AND (cast((unix_timestamp(cast(tpep_dropoff_datetime#11040 as timestamp), yyyy-MM-dd HH:mm:ss, Some(Etc/UTC), true) - unix_timestamp(cast(tpep_pickup_datetime#11039 as timestamp), yyyy-MM-dd HH:mm:ss, Some(Etc/UTC), true)) as int) > 0))
#             +- Relation [VendorID#11038L,tpep_pickup_datetime#11039,tpep_dropoff_datetime#11040,passenger_count#11041,trip_distance#11042,RatecodeID#11043,store_and_fwd_flag#11044,PULocationID#11045L,DOLocationID#11046L,payment_type#11047L,fare_amount#11048,extra#11049,mta_tax#11050,tip_amount#11051,tolls_amount#11052,improvement_surcharge#11053,total_amount#11054,congestion_surcharge#11055,airport_fee#11056] parquet
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- == Initial Plan ==
#    ColumnarToRow
#    +- PhotonResultStage
#       +- PhotonSort [n_trips#11236L DESC NULLS LAST]
#          +- PhotonShuffleExchangeSource
#             +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#8698]
#                +- PhotonShuffleExchangeSink rangepartitioning(n_trips#11236L DESC NULLS LAST, 1024)
#                   +- PhotonFilter (n_trips#11236L > 50)
#                      +- PhotonGroupingAgg(limit=None, keys=[PULocationID#11045L, hour#11235], functions=[finalmerge_count(merge count#11468L) AS count(1)#11464L, finalmerge_avg(merge sum#11471, count#11472L) AS avg(tip_amount)#11465, finalmerge_avg(merge sum#11475, count#11476L) AS avg(total_amount)#11466], output=[PULocationID#11045L, hour#11235, n_trips#11236L, avg_tip#11237, avg_total#11238])
#                         +- PhotonShuffleExchangeSource
#                            +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#8690]
#                               +- PhotonShuffleExchangeSink hashpartitioning(PULocationID#11045L, hour#11235, 1024)
#                                  +- PhotonGroupingAgg(limit=None, keys=[PULocationID#11045L, hour#11235], functions=[partial_count(1) AS count#11468L, partial_avg(tip_amount#11051) AS (sum#11471, count#11472L), partial_avg(total_amount#11054) AS (sum#11475, count#11476L)], output=[PULocationID#11045L, hour#11235, count#11468L, sum#11471, count#11472L, sum#11475, count#11476L])
#                                     +- PhotonProject [PULocationID#11045L, tip_amount#11051, total_amount#11054, hour(cast(tpep_pickup_datetime#11039 as timestamp), Some(Etc/UTC)) AS hour#11235]
#                                        +- PhotonScan parquet [tpep_pickup_datetime#11039,tpep_dropoff_datetime#11040,passenger_count#11041,trip_distance#11042,PULocationID#11045L,tip_amount#11051,total_amount#11054] DataFilters: [isnotnull(trip_distance#11042), isnotnull(total_amount#11054), isnotnull(tpep_pickup_datetime#11..., DictionaryFilters: [((trip_distance#11042 > 0.0) AND (trip_distance#11042 < 100.0)), ((passenger_count#11041 >= 1.0)..., Format: parquet, Location: InMemoryFileIndex(12 paths)[dbfs:/Volumes/workspace/default/nyc_taxi/yellow_tripdata_2019-01.parq..., OptionalDataFilters: [], PartitionFilters: [], ReadSchema: struct<tpep_pickup_datetime:timestamp_ntz,tpep_dropoff_datetime:timestamp_ntz,passenger_count:dou..., RequiredDataFilters: [isnotnull(trip_distance#11042), isnotnull(total_amount#11054), isnotnull(tpep_pickup_datetime#11...
#
# == Photon Explanation ==
# The query is fully supported by Photon.

# %%
nparts = 200
nyc_taxi_df_filtered_partitioned = nyc_taxi_df_filtered.repartition(nparts, "PULocationID")

nyc_taxi_df_groupby_PUID = (nyc_taxi_df_filtered_partitioned.groupBy("PULocationID")
         .agg(F.count("*").alias("n_trips"), F.avg("total_amount").alias("avg_total")))
display(nyc_taxi_df_groupby_PUID.limit(20))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>PULocationID</th><th>n_trips</th><th>avg_total</th></tr></thead><tbody><tr><td>26</td><td>4479</td><td>22.17868943960843</td></tr><tr><td>29</td><td>1433</td><td>28.094173063503177</td></tr><tr><td>65</td><td>94187</td><td>20.34511036556757</td></tr><tr><td>191</td><td>2544</td><td>38.39559355345994</td></tr><tr><td>222</td><td>2386</td><td>30.315310142498895</td></tr><tr><td>243</td><td>13553</td><td>20.473413266432168</td></tr><tr><td>54</td><td>2470</td><td>21.188829959514447</td></tr><tr><td>19</td><td>1094</td><td>27.117733089579126</td></tr><tr><td>113</td><td>1243216</td><td>16.256658714345622</td></tr><tr><td>112</td><td>22210</td><td>18.043027915349466</td></tr><tr><td>167</td><td>2808</td><td>21.976203703704535</td></tr><tr><td>155</td><td>2978</td><td>31.148737407657176</td></tr><tr><td>237</td><td>3558623</td><td>14.786242178178084</td></tr><tr><td>241</td><td>1978</td><td>28.054782608696268</td></tr><tr><td>198</td><td>2575</td><td>22.76416699029198</td></tr><tr><td>22</td><td>2649</td><td>24.550547376369387</td></tr><tr><td>130</td><td>13463</td><td>54.13811557602614</td></tr><tr><td>196</td><td>7747</td><td>34.55177875306452</td></tr><tr><td>7</td><td>110077</td><td>14.2571849705416</td></tr><tr><td>77</td><td>2235</td><td>26.459677852349778</td></tr></tbody></table></div>

# %%
out_path = "/Volumes/workspace/default/nyc_taxi/processed/2019_stats"

nyc_taxi_df_filtered_daily_stats.write.mode("overwrite").parquet(out_path)

# %%
display(dbutils.fs.ls(out_path))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/workspace/default/nyc_taxi/processed/2019_stats/_SUCCESS</td><td>_SUCCESS</td><td>0</td><td>1762918347000</td></tr><tr><td>dbfs:/Volumes/workspace/default/nyc_taxi/processed/2019_stats/_committed_4149569641990917045</td><td>_committed_4149569641990917045</td><td>124</td><td>1762915069000</td></tr><tr><td>dbfs:/Volumes/workspace/default/nyc_taxi/processed/2019_stats/_committed_7918402241361222417</td><td>_committed_7918402241361222417</td><td>234</td><td>1762918346000</td></tr><tr><td>dbfs:/Volumes/workspace/default/nyc_taxi/processed/2019_stats/_committed_vacuum1728349989606344054</td><td>_committed_vacuum1728349989606344054</td><td>96</td><td>1762918347000</td></tr><tr><td>dbfs:/Volumes/workspace/default/nyc_taxi/processed/2019_stats/_started_7918402241361222417</td><td>_started_7918402241361222417</td><td>0</td><td>1762918346000</td></tr><tr><td>dbfs:/Volumes/workspace/default/nyc_taxi/processed/2019_stats/part-00000-tid-7918402241361222417-44fe9199-520f-43c7-99d0-91b4b7487201-258-1.c000.snappy.parquet</td><td>part-00000-tid-7918402241361222417-44fe9199-520f-43c7-99d0-91b4b7487201-258-1.c000.snappy.parquet</td><td>13464</td><td>1762918346000</td></tr></tbody></table></div>

# %%
transform = (nyc_taxi_df_filtered
     .withColumn("hour", F.hour("pickup_dt"))
     .filter(F.col("trip_distance") > 1)
    )
print("Declared 't' — no action yet. ")

print("Trigger an action (count):", transform.count())

transform2 = transform.withColumn(
    "tip_rate",
    F.try_divide(F.col("tip_amount"), F.col("total_amount"))
)
print("Declared 't2' — still lazy.")
display(transform2.limit(5))
# Out:
# Declared 't' — no action yet.
# Trigger an action (count): 60016055
# Declared 't2' — still lazy.
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>tpep_pickup_datetime</th><th>tpep_dropoff_datetime</th><th>passenger_count</th><th>trip_distance</th><th>PULocationID</th><th>DOLocationID</th><th>payment_type</th><th>fare_amount</th><th>tip_amount</th><th>total_amount</th><th>pickup_dt</th><th>dropoff_dt</th><th>trip_seconds</th><th>cost_per_mile</th><th>year</th><th>month</th><th>hour</th><th>tip_rate</th></tr></thead><tbody><tr><td>2019-03-01T00:25:27.000</td><td>2019-03-01T00:36:37.000</td><td>2.0</td><td>3.7</td><td>95</td><td>130</td><td>1</td><td>13.0</td><td>0.7</td><td>15.0</td><td>2019-03-01T00:25:27.000Z</td><td>2019-03-01T00:36:37.000Z</td><td>670</td><td>4.0540540540540535</td><td>2019</td><td>3</td><td>0</td><td>0.04666666666666666</td></tr><tr><td>2019-03-01T00:05:21.000</td><td>2019-03-01T00:38:23.000</td><td>1.0</td><td>14.1</td><td>249</td><td>28</td><td>1</td><td>41.0</td><td>10.1</td><td>60.66</td><td>2019-03-01T00:05:21.000Z</td><td>2019-03-01T00:38:23.000Z</td><td>1982</td><td>4.3021276595744675</td><td>2019</td><td>3</td><td>0</td><td>0.16650181338608638</td></tr><tr><td>2019-03-01T00:48:55.000</td><td>2019-03-01T01:06:03.000</td><td>1.0</td><td>9.6</td><td>138</td><td>98</td><td>2</td><td>27.0</td><td>0.0</td><td>28.3</td><td>2019-03-01T00:48:55.000Z</td><td>2019-03-01T01:06:03.000Z</td><td>1028</td><td>2.947916666666667</td><td>2019</td><td>3</td><td>0</td><td>0.0</td></tr><tr><td>2019-03-01T00:45:03.000</td><td>2019-03-01T00:49:38.000</td><td>1.0</td><td>1.2</td><td>246</td><td>48</td><td>2</td><td>6.0</td><td>0.0</td><td>9.8</td><td>2019-03-01T00:45:03.000Z</td><td>2019-03-01T00:49:38.000Z</td><td>275</td><td>8.166666666666668</td><td>2019</td><td>3</td><td>0</td><td>0.0</td></tr><tr><td>2019-02-28T19:52:45.000</td><td>2019-02-28T20:01:54.000</td><td>1.0</td><td>5.65</td><td>132</td><td>197</td><td>2</td><td>17.0</td><td>0.0</td><td>18.3</td><td>2019-02-28T19:52:45.000Z</td><td>2019-02-28T20:01:54.000Z</td><td>549</td><td>3.238938053097345</td><td>2019</td><td>2</td><td>19</td><td>0.0</td></tr></tbody></table></div>

# %%
start = time.time()
nyc_taxi_df_filtered_daily_stats.count()
print("First count (before caching):", round(time.time() - start, 2), "seconds")

nyc_taxi_df_filtered_daily_stats.createOrReplaceTempView("daily_stats_temp")

start = time.time()
spark.sql("SELECT COUNT(*) FROM daily_stats_temp").collect()
print("Second count (after temp view reuse):", round(time.time() - start, 2), "seconds")
# Out:
# First count (before caching): 1.83 seconds
# Second count (after temp view reuse): 1.92 seconds
